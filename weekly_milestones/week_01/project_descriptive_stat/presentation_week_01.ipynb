# %% [markdown]
# # First experiment with data visualisation and Basic statistics
# ### Kateryna Padiash
# ### Spiced Academy - Bergamot Encoders

# %% [markdown]
# * Working with Seaborn
# * Mergin, melding and plotting

# %% [markdown]
# ![SegmentLocal](output.gif "segment")

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import plotly.graph_objects as go
import plotly.express as exp

# %%
data = pd.read_csv('../data/df_full.csv', index_col=0)
data_70_15 =  data[data['year'].between(1970,2016)]
# Out:
#            country  year  fert         pop   life continent
# 35     Afghanistan  1970  7.67  11121097.0  37.20      Asia
# 36     Afghanistan  1971  7.67  11412821.0  37.70      Asia
# 37     Afghanistan  1972  7.67  11716896.0  38.19      Asia
# 38     Afghanistan  1973  7.67  12022514.0  38.67      Asia
# 39     Afghanistan  1974  7.67  12315553.0  39.14      Asia
# ...            ...   ...   ...         ...    ...       ...
# 13441     Zimbabwe  2011  3.64  14255592.0  51.60    Africa
# 13442     Zimbabwe  2012  3.56  14565482.0  54.20    Africa
# 13443     Zimbabwe  2013  3.49  14898092.0  55.70    Africa
# 13444     Zimbabwe  2014  3.41  15245855.0  57.00    Africa
# 13445     Zimbabwe  2015  3.35  15602751.0  59.30    Africa
#
# [7636 rows x 6 columns]

# %%
exp.scatter(data_70_15, x='life', y = 'fert', animation_frame='year', animation_group="country", size = 'pop', 
            color = 'continent', hover_name='country', log_x=True, size_max=100, height=600, range_x=[30,90],
            range_y = [0, 8])

# %%
df_corr = data_70_15.groupby(['country', 'year']).agg({'fert':'mean', 'pop':'mean', 'life': 'mean'}).reset_index()
df_corr = df_corr.corr()
df_corr
# Out:
# /tmp/ipykernel_3413/2196270819.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#           year      fert       pop      life
# year  1.000000 -0.387592  0.052360  0.350352
# fert -0.387592  1.000000 -0.097164 -0.819100
# pop   0.052360 -0.097164  1.000000  0.019110
# life  0.350352 -0.819100  0.019110  1.000000

# %%
fig = exp.imshow(df_corr, text_auto=True, aspect="auto", color_continuous_scale='RdBu_r')

fig.update_layout(margin = dict(t=100,r=100,b=100,l=100),
    showlegend = True,
    width = 600, height = 600,
    autosize = False )
fig.show()

# %%
df_agg1 = data_70_15.groupby(['year',  'continent']).agg({'fert':'mean', 'pop':'mean', 'life': 'mean'}).reset_index()
df_agg1
# Out:
#      year              continent      fert           pop       life
# 0    1970                 Africa  6.702653  6.718093e+06  48.147143
# 1    1970                   Asia  6.126216  5.427710e+07  57.593514
# 2    1970  Australia and Oceania  5.430000  2.133778e+06  58.635556
# 3    1970                 Europe  2.514000  1.333825e+07  70.580750
# 4    1970          North America  4.973158  1.694425e+07  63.519474
# ..    ...                    ...       ...           ...        ...
# 271  2015                   Asia  2.403514  1.134098e+08  73.791892
# 272  2015  Australia and Oceania  3.103333  4.252114e+06  69.666667
# 273  2015                 Europe  1.627750  1.512268e+07  78.755000
# 274  2015          North America  2.238421  2.990037e+07  75.152632
# 275  2015          South America  2.318333  3.484797e+07  75.141667
#
# [276 rows x 5 columns]

# %%
df_agg1#create animated bar plot
exp.bar(df_agg1,  "continent", ['fert','life'], color= 'continent', animation_frame = 'year', hover_name = 'continent', 
                  range_y=[0, 85], barmode="group", title ='Avarage life')

# %%
#'tealrose', 'tempo', 'temps', 'thermal', 'tropic', 'turbid', 'turbo', 'twilight', 'viridis', 'ylgn', 'ylgnbu', 'ylorbr', 'ylorrd'

exp.choropleth(data_70_15, locations = 'country', color="fert",
              hover_name="country", locationmode = 'country names',  
              animation_frame="year",    
              color_continuous_scale='tropic',  
              height=900 ,title='World fertility numbers by countries and years')

# %%
#'tealrose', 'tempo', 'temps', 'thermal', 'tropic', 'turbid', 'turbo', 'twilight', 'viridis', 'ylgn', 'ylgnbu', 'ylorbr', 'ylorrd'

exp.choropleth(data_70_15, locations = 'country', color="life",
              hover_name="country", locationmode = 'country names',  
              animation_frame="year",    
              color_continuous_scale='thermal',  
              height=900 ,title='World fertility numbers by countries and years')
